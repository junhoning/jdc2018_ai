# %% [markdown]
# # 파이썬 기본 사용법

# %% [markdown]
# https://wikidocs.net/2

# %%
# dtype 이해하기 
'Coding_Camp'
1
3.2
# Out:
# 3.2

# %%
print("Weclome to the camp")
# Out:
# Weclome to the camp

# %%
# 변수 지정 해주기 
name = 'JDC'
date = 17
time = 0.5

# %%
result = date + time
result
# Out:
# 17.5

# %%
# 함수 사용하기 
def summation(x, y):
    sum_num = x + y
    return sum_num

# %%
summation(10, 5)
# Out:
# 15

# %%
# 자료형 이해가기

# List 
[1, 4, 6, 'name']

# Tuple
(1, 'random', 6, 1.)

# Dictionary
dict_example = {'name': 'JoonHo Lee', 'age': 30, 'location': 'Jeju', 'height':180.2}

dict_example['name']
# Out:
# 'JoonHo Lee'

# %%
# For문 이해하기 

ex_list = ['a', 'b', 'c', 'd']

for val in ex_list:
    print(val)
# Out:
# a
# b
# c
# d

# %% [markdown]
# # 이미지 열기

# %%
from PIL import Image

# %%
image = Image.open('drive/image.jpg')

# %%
import requests
from io import BytesIO


# URL로 주소 받아 이미지 열기 
url = 'https://i.ytimg.com/vi/tjr_SEw76zM/maxresdefault.jpg'

response = requests.get(url)
image = Image.open(BytesIO(response.content))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x1DC03E3BC18>

# %% [markdown]
# ## Array의 개념

# %%
import numpy as np

import matplotlib.pyplot as plt
% matplotlib inline

# %%
image = np.array(image)

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
ex = image[:, :, 0]

# %%
plt.imshow(ex)
plt.show()

# %% [markdown]
# # Google Colab 사용하기

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    print('User uploaded file "{name}"with length {length} bytes'.format(
    name=fn, length=len(uploaded[fn])))

# %% [markdown]
# ## 드라이브 마운트 하기
#
# 1. google.colab.drive를 import 한다.
# 2. drive.mount(마운트 이름)  # 마운트 이름은 본인이 원하는대로 적으면 된다.
# 3. 그럼 현재 경로에서 'drive/My Drive/' 경로가 추가 된 것을 확인 할 수 있다.

# %%
import os
from glob import glob

from google.colab import drive

# %%
os.listdir('drive/')

# %%
os.listdir('drive/My Drive')

# %%
drive.mount('drive/')
